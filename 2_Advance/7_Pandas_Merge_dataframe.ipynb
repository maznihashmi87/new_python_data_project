# %%
#Import Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %store -r df_US_pivot

# %%
df_US_softwear_pivot = pd.read_csv(r"C:\Users\Shah Alam\Downloads\job_postings.csv", index_col="job_posted_month")
df_US_softwear_pivot
# Out:
#                   Front-End Developer  ...  UI/UX Designer
# job_posted_month                       ...
# January                         13619  ...            4348
# February                        11456  ...            4284
# March                           11102  ...            4159
# April                           14037  ...            4220
# May                             12126  ...            4980
# June                            12003  ...            4781
# July                            11914  ...            4344
# August                          11571  ...            4104
# September                       14016  ...            4094
# October                         11419  ...            4389
# November                        13771  ...            4099
# December                        14033  ...            4367
#
# [12 rows x 4 columns]

# %%
df_US_pivot
# Out:
# job_title_short   Business Analyst  ...  Software Engineer
# job_posted_month                    ...
# January                        527  ...                114
# February                       447  ...                 90
# March                          438  ...                115
# April                          565  ...                112
# May                            279  ...                 90
# June                           446  ...                 93
# July                           581  ...                153
# August                         903  ...                194
# September                      897  ...                228
# October                        932  ...                219
# November                       719  ...                194
# December                       648  ...                212
#
# [12 rows x 10 columns]

# %%
df_US_merged = df_US_pivot.merge(df_US_softwear_pivot, on='job_posted_month')

# %%
top_5 = (df_US_merged
         .sum() 
         .sort_values(ascending=False)
         .head(5) 
         .index 
         .tolist()
         )
top_5
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'Data Analyst',
#  'Data Scientist']

# %%
df_US_merged[top_5].plot(kind='line')
plt.title('Monthly Job Postings for top tech jobs in the US')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.ylim(0, 22000)
plt.legend()
plt.show()
